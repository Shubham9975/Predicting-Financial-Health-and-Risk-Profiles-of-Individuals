# %%
# importing needed libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read train data
train_df = pd.read_csv("train.csv")
train_df.head()
# Out:
#    Age  Gender  Marital Status  Number of Dependents  Household Size  \
# 0   56       1               2                     4               5
# 1   69       0               1                     2               6
# 2   46       1               2                     1               2
# 3   32       0               0                     2               6
# 4   60       0               1                     1               5
#
#    Education Level  Occupation  Years in Current Job  Income Level  \
# 0                2           2                    11             0
# 1                1           0                    18             2
# 2                0           4                    17             2
# 3                0           0                    20             2
# 4                0           2                    18             0
#
#    Credit Score  ...  Local Unemployment Rate  Inflation Rate  Interest Rates  \
# ...

# %%
#check data types and null values
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 48 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   Age                                   100000 non-null  int64
#  1   Gender                                100000 non-null  int64
#  2   Marital Status                        100000 non-null  int64
#  3   Number of Dependents                  100000 non-null  int64
#  4   Household Size                        100000 non-null  int64
#  5   Education Level                       100000 non-null  int64
#  6   Occupation                            100000 non-null  int64
#  7   Years in Current Job                  100000 non-null  int64
#  8   Income Level                          100000 non-null  int64
#  9   Credit Score                          100000 non-null  int64
#  10  Number of Credit Inquiries            100000 non-null  int64
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
# numerical stats
train_df.describe()
# Out:
#                  Age         Gender  Marital Status  Number of Dependents  \
# count  100000.000000  100000.000000   100000.000000         100000.000000
# mean       48.525990       0.501320        1.002370              1.999230
# std        17.886768       0.500001        0.814721              1.414075
# min        18.000000       0.000000        0.000000              0.000000
# 25%        33.000000       0.000000        0.000000              1.000000
# 50%        48.000000       1.000000        1.000000              2.000000
# 75%        64.000000       1.000000        2.000000              3.000000
# max        79.000000       1.000000        2.000000              4.000000
#
#        Household Size  Education Level     Occupation  Years in Current Job  \
# count   100000.000000    100000.000000  100000.000000         100000.000000
# mean         4.498360         0.998540       1.994090             14.531440
# ...

# %%
# checking distribution of target classes
train_df['Risk Profile'].value_counts()
# Out:
# Risk Profile
# 1    33455
# 0    33310
# 2    33235
# Name: count, dtype: int64

# %%
#check distribution over age
train_df['Age'].hist()
# Out:
# <Axes: >

# %%
# distribution over age
train_df['Gender'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
# credit score distribution of target and overlap
sns.boxplot(x='Risk Profile', y='Credit Score', data=train_df)
# Out:
# <Axes: xlabel='Risk Profile', ylabel='Credit Score'>

# %%
# age distribution and overlap between target
sns.boxplot(x='Risk Profile', y='Age', data=train_df)
# Out:
# <Axes: xlabel='Risk Profile', ylabel='Age'>

# %%
# checking correlation of each feature and target
train_df.corr().iloc[:,-1].sort_values(ascending=False)
# Out:
# Risk Profile                            1.000000
# Gender                                  0.006095
# Years in Current Job                    0.006044
# Age                                     0.005119
# Number of Loans Taken                   0.003521
# Inflation Rate                          0.003303
# Mortgage Information                    0.003090
# City or Region of Residence             0.002959
# Financial Stability of Parents          0.002952
# Number of Credit Cards Held             0.002802
# Interest Rates                          0.001889
# Financial Planner Involvement           0.001736
# Investment Accounts                     0.001616
# Income Level                            0.001548
# Number of Dependents                    0.001161
# Utility Bills Payment History           0.001067
# Life Insurance Adequacy                 0.000949
# Divorce History                         0.000939
# Local Unemployment Rate                 0.000894
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %%
# split data in feature and target
X = train_df.iloc[:, :-1]
y = train_df['Risk Profile']

# %%
# split dataset in train and test
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size=0.2, 
                                                    random_state=27)

# %%
# random forest model
forest_model = RandomForestClassifier(n_estimators=100, random_state=27)

# %%
# building the model
forest_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=27)

# %%
y_pred = forest_model.predict(X_test)

# %%
# Evaluating the model
print("Accuracy Score:", accuracy_score(y_test, y_pred))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy Score: 0.3281
#
# Confusion Matrix:
# [[2289 2356 2084]
#  [2279 2285 2046]
#  [2251 2422 1988]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.34      0.34      0.34      6729
#            1       0.32      0.35      0.33      6610
#            2       0.32      0.30      0.31      6661
#
#     accuracy                           0.33     20000
#    macro avg       0.33      0.33      0.33     20000
# weighted avg       0.33      0.33      0.33     20000

# %%
from sklearn.model_selection import GridSearchCV

# %%
# hyper parameter tuning
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [10, 20, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'criterion': ['gini', 'entropy']
}

# %%
grid_search = GridSearchCV(estimator=RandomForestClassifier(random_state=27),
                           param_grid=param_grid,
                           cv=3,
                           n_jobs=-1,
                           verbose=2)

# %%
grid_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 162 candidates, totalling 486 fits
# GridSearchCV(cv=3, estimator=RandomForestClassifier(random_state=27), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [10, 20, None],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 200, 300]},
#              verbose=2)

# %%
# best model after hyper parameter tuning
print("Best Parameters:", grid_search.best_params_)
# Out:
# Best Parameters: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300}

# %%
forestCV_model = grid_search.best_estimator_

# %%
y_pred_forestCV = forestCV_model.predict(X_test)

# %%
# Evaluating model
print("Accuracy Score (Tuned):", accuracy_score(y_test, y_pred_forestCV))
print("\nConfusion Matrix (Tuned):")
print(confusion_matrix(y_test, y_pred_forestCV))
print("\nClassification Report (Tuned):")
print(classification_report(y_test, y_pred_forestCV))
# Out:
# Accuracy Score (Tuned): 0.33685
#
# Confusion Matrix (Tuned):
# [[2185 2415 2129]
#  [2093 2424 2093]
#  [2119 2414 2128]]
#
# Classification Report (Tuned):
#               precision    recall  f1-score   support
#
#            0       0.34      0.32      0.33      6729
#            1       0.33      0.37      0.35      6610
#            2       0.34      0.32      0.33      6661
#
#     accuracy                           0.34     20000
#    macro avg       0.34      0.34      0.34     20000
# weighted avg       0.34      0.34      0.34     20000

# %%
# checking feature importances
importances = forest_model.feature_importances_
importances
# Out:
# array([0.03925268, 0.00722175, 0.01212413, 0.01724717, 0.02231547,
#        0.01237106, 0.01903163, 0.03536623, 0.01243002, 0.04415344,
#        0.02665681, 0.00735754, 0.01258971, 0.0073368 , 0.01250977,
#        0.01253919, 0.01243581, 0.00754536, 0.00755176, 0.04452173,
#        0.04472706, 0.0448035 , 0.01791003, 0.04487994, 0.04495729,
#        0.04506319, 0.0192058 , 0.03798721, 0.00737023, 0.00746232,
#        0.01609885, 0.00747166, 0.00736512, 0.00725304, 0.00766677,
#        0.00760852, 0.00721737, 0.00748872, 0.04492314, 0.04473119,
#        0.04470436, 0.01203777, 0.02559421, 0.00764923, 0.04502873,
#        0.00755581, 0.0126809 ])

# %%
features = X.columns

# %%
feature_importance_df = pd.DataFrame({
    'Feature': features,
    'Importance': importances
})

# %%
# sort by values of importance of random forest model before hyperparameter tuning
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# %%
feature_importance_df
# Out:
#                                  Feature  Importance
# 25                 Emergency Fund Status    0.045063
# 44                  Debt-to-Income Ratio    0.045029
# 24                   Investment Accounts    0.044957
# 38               Local Unemployment Rate    0.044923
# 23                  Mortgage Information    0.044880
# 21                          Savings Rate    0.044803
# 39                        Inflation Rate    0.044731
# 20                     Credit Card Usage    0.044727
# 40                        Interest Rates    0.044704
# 19              Average Monthly Expenses    0.044522
# 9                           Credit Score    0.044153
# 0                                    Age    0.039253
# 27                 Bank Account Activity    0.037987
# 7                   Years in Current Job    0.035366
# 10            Number of Credit Inquiries    0.026657
# 42                        Risk Tolerance    0.025594
# 4                         Household Size    0.022315
# ...

# %%
importances1 = forestCV_model.feature_importances_
importances1
# Out:
# array([0.03982803, 0.00674897, 0.01193999, 0.01699269, 0.02201871,
#        0.01185781, 0.01857237, 0.03554253, 0.01208129, 0.04470105,
#        0.02643333, 0.00706181, 0.01210455, 0.00693756, 0.01207711,
#        0.01203316, 0.01216612, 0.00705448, 0.00707336, 0.04577344,
#        0.04594612, 0.04619489, 0.01800254, 0.04623006, 0.0459686 ,
#        0.04612593, 0.01842656, 0.03844371, 0.00697321, 0.00705248,
#        0.01581258, 0.00703826, 0.00696511, 0.00670473, 0.00713973,
#        0.00694629, 0.00678837, 0.00707042, 0.04602994, 0.04616542,
#        0.04580327, 0.01139715, 0.02535318, 0.00718603, 0.04607035,
#        0.00710274, 0.01206397])

# %%
feature_importance_df2 = pd.DataFrame({
    'Feature': features,
    'Importance': importances1
})

# %%
# sort by values of importance of random forest model after hyperparameter tuning
feature_importance_df2 = feature_importance_df2.sort_values(by='Importance', ascending=False)
feature_importance_df2
# Out:
#                                  Feature  Importance
# 23                  Mortgage Information    0.046230
# 21                          Savings Rate    0.046195
# 39                        Inflation Rate    0.046165
# 25                 Emergency Fund Status    0.046126
# 44                  Debt-to-Income Ratio    0.046070
# 38               Local Unemployment Rate    0.046030
# 24                   Investment Accounts    0.045969
# 20                     Credit Card Usage    0.045946
# 40                        Interest Rates    0.045803
# 19              Average Monthly Expenses    0.045773
# 9                           Credit Score    0.044701
# 0                                    Age    0.039828
# 27                 Bank Account Activity    0.038444
# 7                   Years in Current Job    0.035543
# 10            Number of Credit Inquiries    0.026433
# 42                        Risk Tolerance    0.025353
# 4                         Household Size    0.022019
# ...

# %%
# taking top features to built model
top_features = [
    'Mortgage Information',
    'Savings Rate',
    'Inflation Rate',
    'Emergency Fund Status',
    'Debt-to-Income Ratio',
    'Local Unemployment Rate',
    'Investment Accounts',
    'Credit Card Usage',
    'Interest Rates',
    'Average Monthly Expenses',
    'Credit Score',
    'Age',
    'Bank Account Activity',
    'Years in Current Job',
    'Number of Credit Inquiries'
]

# %%
X = train_df[top_features]
y = train_df['Risk Profile']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size=0.2, 
                                                    random_state=27)

# %%
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [5, 10, 15],
    'min_samples_split': [2, 5],
    'criterion': ['gini', 'entropy']
}

# %%
grid_search = GridSearchCV(RandomForestClassifier(random_state=27),
                           param_grid,
                           cv=3,
                           scoring='accuracy',
                           verbose=2,
                           n_jobs=-1)

# %%
grid_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# GridSearchCV(cv=3, estimator=RandomForestClassifier(random_state=27), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [5, 10, 15], 'min_samples_split': [2, 5],
#                          'n_estimators': [100, 200]},
#              scoring='accuracy', verbose=2)

# %%
best_model = grid_search.best_estimator_

# %%
best_model
# Out:
# RandomForestClassifier(max_depth=15, n_estimators=200, random_state=27)

# %%
y_pred = best_model.predict(X_test)

# %%
print("Tuned Accuracy Score:", accuracy_score(y_test, y_pred))
print("\nConfusion Matrix (Tuned):\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report (Tuned):\n", classification_report(y_test, y_pred))
# Out:
# Tuned Accuracy Score: 0.33735
#
# Confusion Matrix (Tuned):
#  [[2126 2634 1969]
#  [2027 2621 1962]
#  [2079 2582 2000]]
#
# Classification Report (Tuned):
#                precision    recall  f1-score   support
#
#            0       0.34      0.32      0.33      6729
#            1       0.33      0.40      0.36      6610
#            2       0.34      0.30      0.32      6661
#
#     accuracy                           0.34     20000
#    macro avg       0.34      0.34      0.34     20000
# weighted avg       0.34      0.34      0.34     20000

# %%
# random forest models doesnt show improvements trying XGBoost model
from xgboost import XGBClassifier

# %%
xgb = XGBClassifier(
    objective='multi:softmax',
    num_class=3,
    eval_metric='mlogloss',
    random_state=42
)

# %%
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None, num_class=3, ...)

# %%
y_pred_xgb = xgb.predict(X_test)

# %%
print("XGBoost Accuracy:", accuracy_score(y_test, y_pred_xgb))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_xgb))
print("Classification Report:\n", classification_report(y_test, y_pred_xgb))
# Out:
# XGBoost Accuracy: 0.33275
# Confusion Matrix:
#  [[2209 2284 2236]
#  [2150 2231 2229]
#  [2229 2217 2215]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.34      0.33      0.33      6729
#            1       0.33      0.34      0.33      6610
#            2       0.33      0.33      0.33      6661
#
#     accuracy                           0.33     20000
#    macro avg       0.33      0.33      0.33     20000
# weighted avg       0.33      0.33      0.33     20000

# %% [markdown]
# ### As the data is synthetic every feature is highly overlapping between all target variable.
# ### The feature are also not showing strong correlation between target variable
#
# ### but as we have seen throgh following are the top features that are affecting financial health of the individuals
#     'Mortgage Information',
#     'Savings Rate',
#     'Inflation Rate',
#     'Emergency Fund Status',
#     'Debt-to-Income Ratio',
#     'Local Unemployment Rate',
#     'Investment Accounts',
#     'Credit Card Usage',
#     'Interest Rates',
#     'Average Monthly Expenses',
#     'Credit Score',
#     'Age',
#     'Bank Account Activity',
#     'Years in Current Job',
#     'Number of Credit Inquiries'
